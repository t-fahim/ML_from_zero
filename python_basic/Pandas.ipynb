# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a Python library used to analyze data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.3

# %% [markdown]
# # Panda's Series and DataFrame

# %% [markdown]
# ## Panda's Series
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type

# %%
# creating pandas series
data = ["BMW", "Volvo", "Ford"]
s = pd.Series(data)
print(s)
# Out:
# 0      BMW
# 1    Volvo
# 2     Ford
# dtype: str

# %%
a = (10, 70, 20)
myvar = pd.Series(a)
print(myvar)
print(myvar[1])
# Out:
# 0    10
# 1    70
# 2    20
# dtype: int64
# 70

# %%
a = [10, 70, 20]
myvar = pd.Series(a, index=["x", "y", "z"])
print(myvar)
print(myvar["x"])
# Out:
# x    10
# y    70
# z    20
# dtype: int64
# 10

# %%
# You can also use a key/value object, like a dictionary, when creating a Series.
calories = {"day1": [420, 500], "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    [420, 500]
# day2           380
# day3           390
# dtype: object

# %%
# Create a Series using only data from "day1" and "day2":
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index=["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ## Panda's dataFrame
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#
# Series is like a column, a DataFrame is the whole table.

# %%
dataset = {"cars": ["BMW", "Volvo", "Ford"], "passings": [3, 7, 2]}
df = pd.DataFrame(dataset)
print(df)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
data = {"calories": [420, 380, 390], "duration": [50, 40, 45]}

df = pd.DataFrame(data)

print(df)
print(type(df))
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# <class 'pandas.DataFrame'>

# %%
data = {"calories": [420, 380, 390], "duration": [50, 40, 45]}

df1 = pd.DataFrame(
    data, index=["day1", "day2", "day3"]
)  # Add a list of names to give each row a name

print(df1)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# # Locate Row : Pandas use the `loc` & `iloc` attribute to return one or more specified row(s)

# %%
print(df.loc[0])
print(type(df.loc[0]))
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64
# <class 'pandas.Series'>

# %%
print(df.loc[[0, 2]])  # By label (index/column names)
# Out:
#    calories  duration
# 0       420        50
# 2       390        45

# %%
print(df.loc[0:2])  # By label (index/column names)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.iloc[0:2])  # By integer position
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
print(df1.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# # locate Column

# %%
print(df.calories)
# Out:
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %%
print(df["calories"])
# Out:
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %% [markdown]
# # Locate spcific value

# %%
df.loc[2, "duration"]
print(df.loc[1, "duration"])
# Out:
# 40

# %%
print(df.iloc[1, 1])
# Out:
# 40

# %% [markdown]
# #  Load CSV Files Into a DataFrame

# %%
df = pd.read_csv("../data_set/data.csv")
print(df.shape)
print(type(df))
print(df)
# Out:
# (169, 4)
# <class 'pandas.DataFrame'>
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.to_string())  # to_string() to print the entire DataFrame
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head()  # Print head information - top 5 rows
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail()  # Print tail information - bottom 5 rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
# The info() method also tells us how many Non-Null values there are present in each column
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
# Statistical Description
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
print(df.isnull().sum())
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %% [markdown]
# # Read JSON
#
# Big data sets are often stored, or extracted as JSON.
#
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas

# %%
df = pd.read_json("../data_set/data.js")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]>

# %% [markdown]
# # Dictionary as JSON
# JSON = Python Dictionary
#
# JSON objects have the same format as Python dictionaries.
#
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly:

# %%
data = {
    "Duration": {"0": 60, "1": 60, "2": 60, "3": 45, "4": 45, "5": 60},
    "Pulse": {"0": 110, "1": 117, "2": 103, "3": 109, "4": 117, "5": 102},
    "Maxpulse": {"0": 130, "1": 145, "2": 135, "3": 175, "4": 148, "5": 127},
    "Calories": {"0": 409, "1": 479, "2": 340, "3": 282, "4": 406, "5": 300},
}

df = pd.DataFrame(data)
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df.to_csv("../data_set/a.csv")

# %% [markdown]
# # Cleaning Data
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# - Empty cells,
#
# - Data in wrong format,
#
# - Wrong data,
#
# - Duplicates.

# %% [markdown]
# ## Empty Cells:Empty cells can potentially give you a wrong result when you analyze data.

# %% [markdown]
# ### One way to deal with empty cells is to `remove rows` that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %%
df = pd.read_csv("../data_set/data.csv")
print(df.isnull().sum())
print(df.shape)
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64
# (169, 4)

# %%
new_df = df.dropna()
print(new_df.isnull().sum())
print(new_df.shape)
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
# (164, 4)

# %% [markdown]
# `dropna(inplace = True)` will NOT return a new DataFrame, but it will remove all rows containg NULL values from the original DataFrame.

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
print(df.shape)
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
# (164, 4)

# %% [markdown]
# ### replace empty values

# %%
# Replace all NULL values with the number 130:
df.fillna(130, inplace=True)
print(df.shape)
# Out:
# (164, 4)

# %%
# Replace only for specified value
df["Calories"] = df["Calories"].fillna(130)
print(df.shape)
# Out:
# (164, 4)

# %% [markdown]
# ### Replace Using Mean, Median, or Mode
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pandas uses the `mean()` `median()` and `mode()` methods to calculate the respective values for a specified column:

# %%
x = df["Calories"].mean()
print(x)
df["Calories"] = df["Calories"].fillna(x)
print(df.shape)
# Out:
# 375.79024390243904
# (164, 4)

# %%
x = df["Calories"].median()
print(x)
df["Calories"] = df["Calories"].fillna(x)
print(df.shape)
# Out:
# 318.6
# (164, 4)

# %%
x = df["Calories"].mode()[0]
print(x)
df["Calories"] = df["Calories"].fillna(x)
print(df.shape)
# Out:
# 300.0
# (164, 4)

# %% [markdown]
# ## Cleaning Data of Wrong Format

# %% [markdown]
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# To fix it, you have two options:
# - remove the rows, or
# - convert all cells in the columns into the same format.

# %%
df = pd.read_csv("../data_set/dirtydata.csv")
print(df.isnull().sum())
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
print(df["Date"].unique())
# Out:
# <StringArray>
# [''2020/12/01'', ''2020/12/02'', ''2020/12/03'', ''2020/12/04'',
#  ''2020/12/05'', ''2020/12/06'', ''2020/12/07'', ''2020/12/08'',
#  ''2020/12/09'', ''2020/12/10'', ''2020/12/11'', ''2020/12/12'',
#  ''2020/12/13'', ''2020/12/14'', ''2020/12/15'', ''2020/12/16'',
#  ''2020/12/17'', ''2020/12/18'', ''2020/12/19'', ''2020/12/20'',
#  ''2020/12/21'',            nan, ''2020/12/23'', ''2020/12/24'',
#  ''2020/12/25'',     '20201226', ''2020/12/27'', ''2020/12/28'',
#  ''2020/12/29'', ''2020/12/30'', ''2020/12/31'']
# Length: 31, dtype: str

# %%
# Convert the 'Date' column to datetime. Dates in mixed formats are parsed automatically,
# and any invalid or unparseable dates are replaced with NaT.
df["Date"] = pd.to_datetime(df["Date"], format="mixed")

# %%
print(df["Date"].unique())
# Out:
# <DatetimeArray>
# ['2020-12-01 00:00:00', '2020-12-02 00:00:00', '2020-12-03 00:00:00',
#  '2020-12-04 00:00:00', '2020-12-05 00:00:00', '2020-12-06 00:00:00',
#  '2020-12-07 00:00:00', '2020-12-08 00:00:00', '2020-12-09 00:00:00',
#  '2020-12-10 00:00:00', '2020-12-11 00:00:00', '2020-12-12 00:00:00',
#  '2020-12-13 00:00:00', '2020-12-14 00:00:00', '2020-12-15 00:00:00',
#  '2020-12-16 00:00:00', '2020-12-17 00:00:00', '2020-12-18 00:00:00',
#  '2020-12-19 00:00:00', '2020-12-20 00:00:00', '2020-12-21 00:00:00',
#                  'NaT', '2020-12-23 00:00:00', '2020-12-24 00:00:00',
#  '2020-12-25 00:00:00', '2020-12-26 00:00:00', '2020-12-27 00:00:00',
#  '2020-12-28 00:00:00', '2020-12-29 00:00:00', '2020-12-30 00:00:00',
#  '2020-12-31 00:00:00']
# Length: 31, dtype: datetime64[us]

# %%
df.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 0        60 2020-12-01    110       130     409.1
# 1        60 2020-12-02    117       145     479.0
# 2        60 2020-12-03    103       135     340.0
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0

# %%
df.dropna(subset=["Date"], inplace=True)

# %%
print(df["Date"].unique())
# Out:
# <DatetimeArray>
# ['2020-12-01 00:00:00', '2020-12-02 00:00:00', '2020-12-03 00:00:00',
#  '2020-12-04 00:00:00', '2020-12-05 00:00:00', '2020-12-06 00:00:00',
#  '2020-12-07 00:00:00', '2020-12-08 00:00:00', '2020-12-09 00:00:00',
#  '2020-12-10 00:00:00', '2020-12-11 00:00:00', '2020-12-12 00:00:00',
#  '2020-12-13 00:00:00', '2020-12-14 00:00:00', '2020-12-15 00:00:00',
#  '2020-12-16 00:00:00', '2020-12-17 00:00:00', '2020-12-18 00:00:00',
#  '2020-12-19 00:00:00', '2020-12-20 00:00:00', '2020-12-21 00:00:00',
#  '2020-12-23 00:00:00', '2020-12-24 00:00:00', '2020-12-25 00:00:00',
#  '2020-12-26 00:00:00', '2020-12-27 00:00:00', '2020-12-28 00:00:00',
#  '2020-12-29 00:00:00', '2020-12-30 00:00:00', '2020-12-31 00:00:00']
# Length: 30, dtype: datetime64[us]

# %%
df.dropna(subset=["Date", "Calories"], inplace=True)

# %% [markdown]
# ## Fixing Wrong Data
# For small data sets you might be able to replace the wrong data one by one, but not for big data sets.
#
# To replace wrong data for larger data sets you can create some rules, e.g. set some boundaries for legal values, and replace any values that are outside of the boundaries.

# %%
df = pd.read_csv("../data_set/dirtydata.csv")
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# If the value is higher than 120, set it to 120
for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.loc[x, "Duration"] = 120
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    58.125000  103.500000  128.500000  304.680000
# std     13.604435    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    120.000000  130.000000  175.000000  479.000000

# %%
# Delete rows where "Duration" is higher than 120:
for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.drop(x, inplace=True)

# %% [markdown]
# Pandas - Removing Duplicates
#
# Duplicate rows are rows that have been registered more than one time.

# %%
print(df.shape)
print(df.duplicated().sum())
# Out:
# (32, 5)
# 1

# %%
df.drop_duplicates(inplace=True)
print(df.shape)
print(df.duplicated().sum())
# Out:
# (31, 5)
# 0

# %% [markdown]
# # Pandas - Data Correlations
# A great aspect of the Pandas module is the `corr()` method.
#
# The `corr()` method calculates the relationship between each column in your data set.
#
# Note: The `corr()` method ignores "not numeric" columns.

# %%
df = pd.read_csv("../data_set/data.csv")
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# Good Correlation:
#
# "Duration" and "Calories" got a 0.922721 correlation, which is a very good correlation, and we can predict that the longer you work out, the more calories you burn, and the other way around: if you burned a lot of calories, you probably had a long work out.
#
# Bad Correlation:
#
# "Duration" and "Maxpulse" got a 0.009403 correlation, which is a very bad correlation, meaning that we can not predict the max pulse by just looking at the duration of the work out, and vice versa.

# %% [markdown]
# # PANDAS CUT - Bins
# pandas`.cut()` is used to group continuous numerical data into intervals (bins).
#
# Instead of working with every individual value, you categorize values into ranges.

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["age_group"] = pd.cut(
    titanic.age, bins=[0, 20, 40, 60], labels=["0-20", "20,40", "40,60"]
)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone age_group
# 0    man        True  NaN  Southampton    no  False     20,40
# 1  woman       False    C    Cherbourg   yes  False     20,40
# 2  woman       False  NaN  Southampton   yes   True     20,40
# 3  woman       False    C  Southampton   yes  False     20,40
# 4    man        True  NaN  Southampton    no   True     20,40

# %% [markdown]
# # Pandas - Plotting
# Pandas uses the `plot()` method to create diagrams.
#
# We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

# %%
df = pd.read_csv("../data_set/data.csv")
df.plot()
# Out:
# <Axes: >
