# %% [markdown]
# #  Machine Learning With Python: Linear Regression With One Variable
#
# Sample problem of predicting home price in monroe, new jersey (USA)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../data_set/homeprice.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  595000
# 4  4000  760000
# 5  4100  810000

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="area", y="price", color="red", s=100)
plt.xlabel("Area (sq ft)")
plt.ylabel("Price")
plt.title("Area vs Price")
plt.show()

# %%
area = df[["area"]]
area
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000
# 5  4100

# %%
price = df["price"]
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
reg = linear_model.LinearRegression()
reg.fit(area, price)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predict price of a home with area = 3300 sqr ft

# %%
reg.predict(pd.DataFrame({"area": [3300]}))
# Out:
# array([628813.88621022])

# %%
reg.coef_
# Out:
# array([167.30954677])

# %%
reg.intercept_
# Out:
# np.float64(76692.38187078107)
