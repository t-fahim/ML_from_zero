# %% [markdown]
# # Central Tendency
# - Mean
# - Median
# - Mode

# %% [markdown]
# # Mean

# %%
speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
mean = sum(speed) / len(speed)
print(mean)
# Out:
# 89.76923076923077

# %%
print(max(speed))
print(min(speed))
# Out:
# 111
# 77

# %%
# Use the NumPy mean() method to find the average speed
import numpy as np

speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
x = np.mean(speed)
print(x)
# Out:
# 89.76923076923077

# %% [markdown]
# # Median

# %%
# Use the NumPy median() method to find the middle value
import numpy as np

speed = [99, 86, 87, 88, 86, 103, 87, 94, 78, 77, 85, 86]  # even list
x = np.median(speed)
print(x)
# Out:
# 86.5

# %% [markdown]
# # Mode

# %%
# Use the SciPy mode() method to find the number that appears the most
from scipy import stats

speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86, 87]
x = stats.mode(speed)
print(x)
print(x.mode)
print(x.count)
# Out:
# ModeResult(mode=np.int64(86), count=np.int64(3))
# 86
# 3

# %% [markdown]
# # Statistics — Mathematical statistics functions

# %%
import statistics as st

# %%
data = [1, 2, 2, 3, 3, 9, 9]
print(st.mean(data))
print(st.median(data))
print(st.mode(data))
# Out:
# 4.142857142857143
# 3
# 2

# %% [markdown]
# - `median_low()` - Returns the lower of the two middle values when there is an even number of observations.
# - `median_high()` - Returns the higher of the two middle values.
# - `median_grouped()` - Estimates the median for grouped data (data that represents intervals or classes rather than exact values).
# - `multimode()` - Returns all values that occur most frequently.

# %%
l = [1, 2, 3, 4, 4, 5]
print(st.median_low(l))
print(st.median_high(l))
print(st.median_grouped(l))
print(st.multimode(l))
# Out:
# 3
# 4
# 3.5
# [4]

# %% [markdown]
# # Quantile and Percentile

# %%
l = [1, 2, 2, 3, 4, 4, 5]
print(st.quantiles(l))
# Out:
# [2.0, 3.0, 4.0]

# %%
import numpy as np

values = [1, 2, 3, 4, 5, 10]

x = np.quantile(values, [0, 0.25, 0.5, 0.75, 1])
# x = np.quantile(values, [0.25,0.5,0.75])

print(x)
print(x[2])
# Out:
# [ 1.    2.25  3.5   4.75 10.  ]
# 3.5

# %%
# for percentile we have to use numpy
l = [10, 20, 30, 40, 50, 60, 70, 80]
print(np.percentile(l, 25))
print(np.percentile(l, 50))
print(np.percentile(l, 95))
# Out:
# 27.5
# 45.0
# 76.5

# %%
np.percentile(l, [25, 50, 75, 80, 99])
# Out:
# array([27.5, 45. , 62.5, 66. , 79.3])
