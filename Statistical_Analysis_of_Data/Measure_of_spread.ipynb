# %% [markdown]
# # Measure of spread

# %% [markdown]
# ## Use the NumPy `std()` method to find the standard deviation

# %%
import numpy as np

speed = [1, 2, 4, 5]
x = np.std(speed)
print(x)
# Out:
# 1.5811388300841898

# %% [markdown]
# ## Use the NumPy `var()` method to find the variance

# %%
speed = [2, 3, 0, 4, 9, 5, 7]
x = np.var(speed)
print(x)
# Out:
# 7.918367346938775

# %% [markdown]
# ## Using Python's built-in `statistics` module
# - pstdev() - Population standard deviation of data.
# - pvariance() - Population variance of data.
# - stdev() - Sample standard deviation of data.
# - variance() -Sample variance of data.

# %%
from statistics import stdev, variance, pstdev, pvariance

data = [1, 2, 5, 9, 0, 3]
print(stdev(data))
print(pstdev(data))
print(variance(data))
print(pvariance(data))
# Out:
# 3.265986323710904
# 2.9814239699997196
# 10.666666666666666
# 8.88888888888889

# %% [markdown]
# # Statistics for relations between two inputs

# %% [markdown]
# These functions calculate statistics regarding relations between two inputs.
#
# - covariance() : Sample covariance for two variables.
#
# - correlation() : Pearson’s correlation coefficient for two variables.
#
# - linear_regression() : Slope and intercept for simple linear regression.

# %%
import pandas as pd

height = [5.6, 5.9, 6]
weight = [60, 65, 70]
df = pd.DataFrame({"h": height, "w": weight})
df
# Out:
#      h   w
# 0  5.6  60
# 1  5.9  65
# 2  6.0  70

# %%
print(df.corr())
# Out:
#           h         w
# h  1.000000  0.960769
# w  0.960769  1.000000

# %%
print(df.cov())
# Out:
#           h     w
# h  0.043333   1.0
# w  1.000000  25.0

# %%
from statistics import covariance, correlation

print(covariance(height, weight))
print(correlation(height, weight))
# Out:
# 1.0000000000000009
# 0.9607689228305225

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr

# %%
# calculate Pearson's correlation
print(pearsonr(height, weight))
# Out:
# PearsonRResult(statistic=np.float64(0.9607689228305225), pvalue=np.float64(0.1789123750220675))

# %%
print(spearmanr(height, weight))
# Out:
# SignificanceResult(statistic=np.float64(1.0), pvalue=np.float64(0.0))
